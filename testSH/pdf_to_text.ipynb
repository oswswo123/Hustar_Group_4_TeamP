# %%
import PyPDF2

# %%
# PDF 파일 object 생성
pdf_file_obj = open("./data/test_pdf_file1.pdf", "rb")

# PDF Reader Object 생성
pdf_reader = PyPDF2.PdfFileReader(pdf_file_obj)

# PDF File page 숫자 출력
print(pdf_reader.numPages)
# Out:
# 4

# %%
page0_obj = pdf_reader.getPage(0)

page0_obj.extractText()
string_list = page0_obj.extractText().split()
print(string_list)
# Out:
# ['[', '음식료', '∙', '담배', ']', '2Q22', 'F&B', 'Preview:', '외형성장', 'vs.', '원가부담', '64', '매일유업', '(267980)', '2Q22', 'Preview', 'Buy', '(Maintain)', '2Q22', 'Preview', '매일유업의', '2', 'Q', '2', '2', '매출액과', '영업이익은', '각각', '4,050', '억원', '(', '+', '5.2', '%', 'YoY),', '2', '24', '억원', '(', '-', '12.7', '%', 'YoY', ')', '으로', '예상한', '다', '.', '주요제품', '성장세는', '여타업체대비', '견조한', '상황으로', ',', '시장지배력', '또한', '유의미하다', '.', '다만', '대외환경', '악화에', '따른', '원재료비용', '상승', '으로', '단기', '영업이익은', '다소', '눈높이를', '낮출', '필요가', '있으나', ',', '향후', '부담', '축소', '시', '추가', '영업실적', '확대', '가능성을', '열어둔다', '.', '냉장유통이', '필요한', '전통적인', '유제품대비', '온라인', '등', '배송에', '상대적인', '경쟁우위', '요소를', '갖춘', '테트라팩', '수요확대와', '관련된', '카테고리의', '외형성장이', '꾸준하며', ',', '최근', '성장세가', '견조한', '곡물음료', ',', '상하목장', '등', '흐름은', '이익기여', '측면에서도', '긍정적이다', '.', '컵커피', '또한', '가격인상', '효과가', '더해져', '높은', '성장세를', '시현할', '것으로', '판단한다', '.', '다만', '원가', '상승과', '관련한', '부담이', '동시에', '반영되면서', '일부', '품목에서의', '마진하락이', '예상', '되며', ',', '추가적으로', '원유가격의', '물가', '연동제와', '
# ...

# %%
# PDF 파일 object 생성
pdf_file_obj2 = open("./data/test_pdf_file2.pdf", "rb")

# PDF Reader Object 생성
pdf_reader2 = PyPDF2.PdfFileReader(pdf_file_obj2)

# PDF File page 숫자 출력
print(pdf_reader2.numPages)
# Out:
# 6

# %%
page0_obj2 = pdf_reader2.getPage(0)

page0_obj2.extractText()
string_list2 = page0_obj2.extractText().split()
print(string_list2)
# Out:
# ['56', '롯데케미칼', '(011170)', '섣부른', '기대감은', '아직까지', '금물', '•', '2', '분기', '영업이익', '285', '억원', '(', '-', '69.9%QoQ', ',', '-', '95.2%YoY', ')', '으로', '컨센서스', '656', '억원', '하회', '예상', '•', '중국', '봉쇄조치', '장기화에', '따른', '수요', '부진과', '유가', '상승으로', '주요', '제품', '스프레드', '축소', '.', '여수공장', '정기보수로', '약', '500', '억', '내외', '일회성', '비용', '발생하며', '2', '분기', '영업이익은', '전분기', '대비', '대폭', '감소할', '것으로', '전망', '•', '특히', '고가', '납사', '투입으로', '래깅', '기준', '동사', '2', '분기', '가중평균', '스프레드는', '306', '달러', '(', '-', '32%QoQ', ')', '로', '대폭', '축소되었는데', ',', '이는', '2013', '년', '이후', '최저치', '수준', '.', '올레핀', '/', '아로마틱스', '/', '타이탄', '등', '전', '부문에서', '영업이익', '감소', '불가피할', '듯', '•', '첨단소재', '는', '가전', '/', '자동차', '등', '전방', '수요는', '부진했으나', ',', '원재료', 'BPA', '급락이', '긍정적으로', '작용하며', '이익은', '소폭', '증가할', '듯', '•', 'LCUSA', '는', '에탄', '강세로', '원가', '부담', '상승', '.', '유럽의', '러시아산', '가스', '구매중단', '(', '축소', ')', '이후', '미국산', '수입', '증가로', 'Henry', 'Hub', '는', '강세', '예상되는데', '이는', 'LCUSA', '원가를', '가중시킬', '것', '.', '더군다나', 'M
# ...

# %%
# PDF 파일 object 생성
pdf_file_obj3 = open("./data/test_pdf_file3.pdf", "rb")

# PDF Reader Object 생성
pdf_reader3 = PyPDF2.PdfFileReader(pdf_file_obj3)

# PDF File page 숫자 출력
print(pdf_reader3.numPages)
# Out:
# 9

# %%
page0_obj3 = pdf_reader3.getPage(0)

page0_obj3.extractText()
string_list3 = page0_obj3.extractText().split()
print(string_list3)
# Out:
# ['신세계', '(004170/KS｜매수(신규편입)｜T.P', '262,000', '원(신규편입))', '리오프닝', '기대감의', '완전한', '반영', '-', '2Q22', '매출액', '1', '조', '5,321', '억원(YoY', '+10%),', '영업이익', '1,172', '억원(YoY', '+22%)', '전망', '-', '주요', '사업부', '중심으로', '전분기에', '이어', '양호한', '실적', '지속', '전망', '-', '백화점', '본점과', '더불어', '지역', '백화점', '3', '사', '실적', '호조가', '전체', '연결', '영업이익', '증가', '견인', '-', '백화점', '기존점', '성장률의', '개선과', '패션', '및', '잡화', '중심의', '상품', '믹스', '변화로', '수익성', '개선', '-', '투자의견', '매수,', '목표주가', '262,000', '원,', '업종내', '2', 'nd', 'pick', '의견으로', '커버리지', '개시', '주가', '및', '상대수익률', '주가상승률', '절대주가', '상대주가', '1개월', '-16.5%', '-3.1%', '6개월', '-14.5%', '11.1%', '12개월', '-22.9%', '10.0%', '주요', '사업', '부문', '견조한', '실적', '신세계의', '연결기준', '2Q22', '실적은', '1', '조', '5,321', '억원(YoY', '+9.8%),', '영업이익은', '1,172', '억원', '(YoY', '+21.8%)으로', '컨센서스', '(2022.07.04', '기준', '매출액', '1', '조', '7,633', '억원,', '영업이익', '1,252', '억원)를', '다소', '하회할', '전망이다.', '다만', '주요', '사업부를', '중심으로', '전분기에', '이어', '양호', '한', '실적', '모멘텀', '지속이', '전망된다.', '특히', 
# ...

# %%
# PDF 파일 object 생성
pdf_file_obj4 = open("./data/test_pdf_file4.pdf", "rb")

# PDF Reader Object 생성
pdf_reader4 = PyPDF2.PdfFileReader(pdf_file_obj4)

# PDF File page 숫자 출력
print(pdf_reader4.numPages)
# Out:
# 7

# %%
page0_obj4 = pdf_reader4.getPage(0)

page0_obj4.extractText()
string_list4 = page0_obj4.extractText().split()
print(string_list4)
# Out:
# ['2', 'Q2', '2', 'Pr', 'eview', ':', 'QoQ', '반등', ',', '다만', '당사', '및', '컨센서스', '전망치', '미달', '예상', '2', 'Q2', '2', '연결', '영업', '실적은', '매출', '1', '9,867', '억원', '(qoq', '7.7', '%', '),', '영업이익', '3,427', '억원', '(qoq', '13.5', '%', ')', '으', '로서', '전분기', '대비', '매출', '및', '영업이익', '모두', '상당수준', '반등하나', '당사', '종전', '전망치', '및', '시장', '컨', '센서스', '전망치에는', '다소', '미달할', '것으로', '추정한', '다', '.', '2Q22', '연결영업실적은', '당사', '종전', '전망치', '대비로는', '매출은', '4.2%,', '영업이익은', '13.3%', '미달', '할', '것으로', '추정했는데', '매출의', '경우', '콘텐츠', '매출이', 'LDF', '의', '이북재팬', '인수에', '따른', '연결반영', '으로', '전분기', '대비', '14.4%', '대폭', '증가하나', '종전', '전망', '치보다는', '증가폭이', '크지', '않을', '것으로', '추', '정했다', '.', '2Q22', '동향', '감안', ',', '2022', '년', '이후', '전망치', '다소', '하향', '조정', '2Q22', '실적', '전망치', '하향', '조정을', '바탕으로', '2022', '년', '이후', '연간', '실적전망치도', '다소', '하향', '조정', '했다', '.', '참고로', '매출', ',', '영', '업이익', ',', '지배주주순익', '전망치', '조정률은', '2022', '년은', '-', '3.3%,', '-', '9.0%,', '-', '8.5%', '이고', '2023', '년은', '-', '5.2%,', '-', 
# ...
